# %%
import sys
print(sys.version)
# Out:
# 3.5.1 |Anaconda 2.5.0 (64-bit)| (default, Dec  7 2015, 11:16:01)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]

# %%
print("Hello, World!")
# Out:
# Hello, World!
